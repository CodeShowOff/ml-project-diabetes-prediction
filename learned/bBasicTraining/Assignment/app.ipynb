# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = {
    "Hours of Advertising per Week": [1, 2, 3, 4, 5],
    "Units Sold": [10, 20, 30, 40, 50]
}

# %%
df = pd.DataFrame(data)
df

# %%
x = df[["Hours of Advertising per Week"]]
y = df[["Units Sold"]]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
print('x_train', x_train)
print('x_test', x_test)
print('y_train', y_train)
print('y_test', y_test)

# %%
model = LinearRegression()
model.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)
print("predictions: ", y_pred)

# %%
plt.scatter(y_test, y_pred, color="red", s=100)
plt.title("Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.grid("true")
plt.show()

# %%
plt.plot(y_test, y_pred, color="blue")

# %%
new_data1 = {
    "Hours of Advertising per Week": [6, 8],
    "Units Sold": [60, 80]
}

df_new1 = pd.DataFrame(new_data1)
x_new1 = df_new1[['Hours of Advertising per Week']]
y_new1 = df_new1[['Units Sold']]



y_pred = model.predict(x_new1)
print("predictions: ", y_pred)
# Out:
# predictions:  [[60.]
#  [80.]]

# %%
new_data2 = {
    "Hours of Advertising per Week": [9, 10]
}
df_new2 = pd.DataFrame(new_data2)

x_new2 = df_new2[['Hours of Advertising per Week']]
y_pred2 = model.predict(x_new2)

print("Predictions:", y_pred2)
# Out:
# Predictions: [[ 90.]
#  [100.]]
