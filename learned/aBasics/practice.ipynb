# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = {'name': ['Ashish', 'Raj', 'Ram'],
        'age': [27, 39, 22],
        'salary': [50000, 20200, 39423]
}
data

# %%
df = pd.DataFrame(data)
df

# %%
df.describe()

# %%
x=df.drop(columns=(['name','age']))
y=df.drop(columns=(['name','salary']))

# %%
plt.scatter(x,y,color='r')
